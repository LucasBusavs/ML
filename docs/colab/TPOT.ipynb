# %% [markdown]
# ## Install & Imports

# %%
# !pip install tpot

import tpot
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 32.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 17.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11938 sha256=e2dfc7ad540ae1cbe0dc7f177b39e17450a95c2bd4662b001a96a3a7cdf758b4
#   Stored in directory: /root/.cache/pip/wheels/af/f9/87/bf5b3d565c2a007b4dae9d8142dccc85a9f164e517062dd519
# Successfully built stopit
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('HIV.csv', sep=';')
X = dataset.iloc[:, 5:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %% [markdown]
# ## Training the TPOT on the Training set

# %%
tpot_config = {
    'sklearn.neighbors.KNeighborsClassifier': {
        'n_neighbors': range(1, 30),
        'weights': ["uniform", "distance"],
        'p': [1, 2]
    }
}

tpotModel = tpot.TPOTClassifier(generations=5, population_size=50, verbosity=2, config_dict=tpot_config)

# %%
tpotModel.fit(X_train, y_train)
# Out:
# Optimization Progress:   0%|          | 0/300 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.8900656163020617
#
# Generation 2 - Current best internal CV score: 0.8900656163020617
#
# Generation 3 - Current best internal CV score: 0.8900656163020617
#
# Generation 4 - Current best internal CV score: 0.8900656163020617
#
# Generation 5 - Current best internal CV score: 0.8900656163020617
#
# Best pipeline: KNeighborsClassifier(CombineDFs(input_matrix, input_matrix), n_neighbors=29, p=1, weights=distance)
# TPOTClassifier(config_dict={'sklearn.neighbors.KNeighborsClassifier': {'n_neighbors': range(1, 30),
#                                                                        'p': [1,
#                                                                              2],
#                                                                        'weights': ['uniform',
# ...

# %% [markdown]
# ## Predicting the Test set results

# %%
tpotModel.score(X_test, y_test)
# Out:
# 0.947289156626506

# %%
y_pred = tpotModel.predict(X_test)

# %% [markdown]
# ## Making the Confusion Matrix & Classification Report

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
titles_options = [
    ("Confusion matrix")
]
for title in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        tpotModel,
        X_test,
        y_test,
        cmap=plt.cm.Blues,
        normalize = "true",
    )
    disp.ax_.set_title(title)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,
                           tpotModel.predict(X_test)))

# %% [markdown]
# ## Exporting the pipeline.py

# %%
tpotModel.export("test_tpot.py")
